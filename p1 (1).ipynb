# %%
#Day 1 of my Python Trainning

# %%
45-23
# Out:
# 22

# %%
a=12    
print(type(a))    #shows datatype
# Out:
# <class 'int'>

# %%
a=12.5
print(type(a))
# Out:
# <class 'float'>

# %%
a=23
b=45
c=a+b
c              #consider last vale only
# Out:
# 68

# %%
a=23
b=45
c=a+b
print(c)
d=b-a
d
# Out:
# 68
# 22

# %%
str1='hello'
str1.upper()     #capital
# Out:
# 'HELLO'

# %%
str1='HELLu'
str1.lower()      #small
# Out:
# 'hellu'

# %%
len(str1)      #finds length of string
# Out:
# 5
